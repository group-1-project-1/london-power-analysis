# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
files = ['./../data/' + name  for name in os.listdir('./../data')]

data = pd.read_csv(files.pop())
for pathname in files:
    new = pd.read_csv(pathname)
    data = data.append( pd.read_csv(pathname) )
    pass

data = data.astype({'datetime': 'datetime64'})
#data = data.set_index('datetime')

# %%
df=data
plt.figure(figsize=(14,4))
plt.plot(df['datetime'], df['count'], marker='.')
