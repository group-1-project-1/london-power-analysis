# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import pandas as pd

from pickup_utilities import *
df = pd.read_csv("../data/complete.csv")
df['tstamp'] = df.apply(tstampCalc, axis = 1)

# %% [markdown]
# # FA Cup Semi-Final 1

# %%
FA_Cup_SemiFinal_1 = df.loc[df['day']==14].loc[df['month']==4].loc[df['year']==2012]
FA_Cup_SemiFinal_1 = FA_Cup_SemiFinal_1.set_index(FA_Cup_SemiFinal_1["tstamp"])
FA_Cup_SemiFinal_1.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00           624  2012-04-14 00:00:00  2012      4   14     0       0
# 0:30           625  2012-04-14 00:30:00  2012      4   14     0      30
# 1:00           626  2012-04-14 01:00:00  2012      4   14     1       0
# 1:30           627  2012-04-14 01:30:00  2012      4   14     1      30
# 2:00           628  2012-04-14 02:00:00  2012      4   14     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00     10.976    0.332    2.489  ...       13       15       37      188
# 0:30      8.925    0.360    3.078  ...       13       15       37      188
# 1:00      7.654    0.323    2.352  ...       13       15       37      188
# 1:30      7.225    0.373    1.841  ...       13       15       37      188
# 2:00      7.217    0.440    1.938  ...       13       15       37      188
#
#         U_count  count       sigma      mean       std  tstamp
# tstamp
# 0:00          8   1220  198.242000  0.162493  0.281590    0:00
# 0:30          8   1218  297.152999  0.243968  0.581075    0:30
# 1:00          8   1218  266.349001  0.218677  0.524967    1:00
# 1:30          8   1218  230.800000  0.189491  0.439398    1:30
# 2:00          8   1218  201.771000  0.165658  0.357615    2:00
#
# [5 rows x 66 columns]

# %%
# Plot the day's energy consumption.

dfevent = FA_Cup_SemiFinal_1
dtitle = "FA Cup Semi-1 (Football): 4/14/2012 12:30 GMT [5.03m]"
tsb = '12:30'
tse ='14:30'

eventPlotter(dfevent, dtitle, tsb, tse)

# %%
# Plot the day's energy consumption for each Acorn group using a multiline plot.
# extract grouped acorn 

dfevent=  FA_Cup_SemiFinal_1
dtitle = "FA Cup Semi 1: 4/14/2012 12:30 GMT [5.03m]"
tsb   = '12:30'
tse   = '14:30'

eventPlotterAcorn( dfevent, dtitle, tsb, tse )

# %%
# Plot the day's normalized energy consumption for each Acorn group using a multiline plot.


dfevent = FA_Cup_SemiFinal_1
title   = "FA Cup Semi 1 (Football): 4/14/2012 12:30 GMT [5.03m]"
tsb     = '12:30'
tse     = '14:30'

eventPlotterAcorn(dfevent, title, tsb, tse, breaktime='13:30')

# %% [markdown]
# # FA Cup Semi-Final 2

# %%
FA_Cup_SemiFinal_2 = df.loc[df['day']==15].loc[df['month']==4].loc[df['year']==2012]
FA_Cup_SemiFinal_2 = FA_Cup_SemiFinal_2.set_index(FA_Cup_SemiFinal_2["tstamp"])
FA_Cup_SemiFinal_2.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00           672  2012-04-15 00:00:00  2012      4   15     0       0
# 0:30           673  2012-04-15 00:30:00  2012      4   15     0      30
# 1:00           674  2012-04-15 01:00:00  2012      4   15     1       0
# 1:30           675  2012-04-15 01:30:00  2012      4   15     1      30
# 2:00           676  2012-04-15 02:00:00  2012      4   15     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00     10.568    0.425    3.480  ...       13       15       37      189
# 0:30     10.389    0.352    3.735  ...       13       15       37      189
# 1:00      9.904    0.322    2.431  ...       12       15       37      189
# 1:30      9.077    0.325    2.865  ...       13       15       37      189
# 2:00      7.656    0.336    1.991  ...       13       15       37      189
#
#         U_count  count    sigma      mean       std  tstamp
# tstamp
# 0:00          9   1233  197.976  0.160564  0.279974    0:00
# 0:30          9   1235  302.121  0.244632  0.579468    0:30
# 1:00          9   1234  279.276  0.226318  0.540792    1:00
# 1:30          9   1235  247.526  0.200426  0.459966    1:30
# 2:00          9   1235  220.148  0.178257  0.393718    2:00
#
# [5 rows x 66 columns]

# %%
dfevent = FA_Cup_SemiFinal_2
dtitle = "FA Cup Semi 2 (Football): 4/15/2012 18:00 GMT [5.03m]"
tsb = '18:00'
tse ='20:00'

eventPlotter(dfevent, dtitle, tsb, tse)

# %%
dfevent = FA_Cup_SemiFinal_2
dtitle = "FA Cup Semi 2 (Football): 4/15/2012 18:00 GMT [5.03m]"
tsb = '18:00'
tse ='20:00'

eventPlotterAcorn(dfevent, dtitle, tsb, tse)

# %%
dfevent = FA_Cup_SemiFinal_2
title   = "FA Cup Semi 2 (Football): 4/14/2012 12:30 GMT [6.48m]"
tsb     = '18:00'
tse     = '20:00'

eventPlotterAcorn(dfevent, title, tsb, tse, breaktime='19:00')

# %% [markdown]
# # FA Cup Final

# %%
df_fa_cup_05_05 = df.loc[df['day']==5].loc[df['month']==5].loc[df['year']==2012]
df_fa_cup_05_05 = df_fa_cup_05_05.set_index(df_fa_cup_05_05["tstamp"])
df_fa_cup_05_05.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00           192  2012-05-05 00:00:00  2012      5    5     0       0
# 0:30           193  2012-05-05 00:30:00  2012      5    5     0      30
# 1:00           194  2012-05-05 01:00:00  2012      5    5     1       0
# 1:30           195  2012-05-05 01:30:00  2012      5    5     1      30
# 2:00           196  2012-05-05 02:00:00  2012      5    5     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00     13.385    0.701    4.460  ...       28       28       49      319
# 0:30     13.051    0.516    3.962  ...       28       28       49      319
# 1:00     10.203    0.666    4.101  ...       28       28       49      319
# 1:30      9.573    0.590    3.794  ...       28       28       49      319
# 2:00      9.813    0.530    3.660  ...       28       28       49      319
#
#         U_count  count       sigma      mean       std  tstamp
# tstamp
# 0:00         10   1880  287.242000  0.152788  0.242125    0:00
# 0:30         10   1879  382.632001  0.203636  0.480379    0:30
# 1:00         10   1879  349.452000  0.185978  0.443294    1:00
# 1:30         10   1879  318.445002  0.169476  0.387334    1:30
# 2:00         10   1879  289.976000  0.154325  0.334495    2:00
#
# [5 rows x 66 columns]

# %%
dfevent = df_fa_cup_05_05
dtitle = "FA Cup Final: 5/5/2012 17:15"
tsb = '17:00'
tse = '19:00'

eventPlotter(dfevent, dtitle, tsb, tse)

# %%
dfevent = df_fa_cup_05_05
dtitle = "FA Cup Final: 5/5/2012 17:15"
tsb = '17:00'
tse = '19:00'

eventPlotterAcorn(dfevent, dtitle, tsb, tse)

# %%
dfevent = df_fa_cup_05_05
dtitle = "FA Cup Final: 5/5/2012 17:15"
tsb = '17:00'
tse = '19:00'

eventPlotterAcorn(dfevent, dtitle, tsb, tse, breaktime='18:00')
