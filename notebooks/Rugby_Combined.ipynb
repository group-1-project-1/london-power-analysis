# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import pandas as pd

from pickup_utilities import *
df = pd.read_csv("../data/complete.csv")
df['tstamp'] = df.apply(tstampCalc, axis = 1)

# %% [markdown]
# England Vs. Australia (11-17-2012)

# %%
# Creating dataframe for England vs Australia match for November 17, 2012

df_EnglandVsAustralia = df.loc[df['day']==17].loc[df['month']==11].loc[df['year']==2012]
df_EnglandVsAustralia = df_EnglandVsAustralia.set_index(df_EnglandVsAustralia["tstamp"])
df_EnglandVsAustralia.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00           768  2012-11-17 00:00:00  2012     11   17     0       0
# 0:30           769  2012-11-17 00:30:00  2012     11   17     0      30
# 1:00           770  2012-11-17 01:00:00  2012     11   17     1       0
# 1:30           771  2012-11-17 01:30:00  2012     11   17     1      30
# 2:00           772  2012-11-17 02:00:00  2012     11   17     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00     42.964    3.961   25.356  ...      125       86       87      704
# 0:30     36.538    3.163   22.915  ...      125       86       87      705
# 1:00     30.609    2.598   20.264  ...      125       86       87      705
# 1:30     26.751    2.371   16.563  ...      125       86       87      705
# 2:00     25.470    2.121   16.693  ...      125       86       87      705
#
# ...

# %%
# Plot the day's energy consumption.

dfevent = df_EnglandVsAustralia
dtitle = "England vs Australia Match 14:30 GMT [5.03m]"
tsb = '14:30'
tse ='16:30'

eventPlotter(dfevent, dtitle, tsb, tse)

# %%
# Plot the day's energy consumption for each Acorn group using a multiline plot.
# extract grouped acorn 

dfevent=  df_EnglandVsAustralia
dtitle = "England vs Australia Match 14:30 GMT [5.03m]"
tsb = '14:30'
tse ='16:30'

eventPlotterAcorn( dfevent, dtitle, tsb, tse )

# %%
# Plot the day's normalized energy consumption for each Acorn group using a multiline plot.


dfevent=  df_EnglandVsAustralia
title = "England vs Australia Match 14:30 GMT [5.03m]"
tsb = '14:30'
tse ='16:30'

eventPlotterAcorn(dfevent, title, tsb, tse, breaktime='15:30')

# %% [markdown]
# England Vs South Africa (11-24-2012)

# %%
# Create a dataframe representing energy consumption for November 24th 2012, the day
# of the England vs. South Africa Rugby game.

df_Eng_Sth_Afr_11_24 = df.loc[df['day']==24].loc[df['month']==11].loc[df['year']==2012]
df_Eng_Sth_Afr_11_24 = df_Eng_Sth_Afr_11_24.set_index(df_Eng_Sth_Afr_11_24["tstamp"])
df_Eng_Sth_Afr_11_24.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00          1104  2012-11-24 00:00:00  2012     11   24     0       0
# 0:30          1105  2012-11-24 00:30:00  2012     11   24     0      30
# 1:00          1106  2012-11-24 01:00:00  2012     11   24     1       0
# 1:30          1107  2012-11-24 01:30:00  2012     11   24     1      30
# 2:00          1108  2012-11-24 02:00:00  2012     11   24     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00     46.684    4.876   25.638  ...      125       87       87      706
# 0:30     36.259    3.297   23.269  ...      125       87       87      705
# 1:00     30.856    3.579   20.002  ...      125       87       87      705
# 1:30     30.647    3.352   18.607  ...      125       87       87      705
# 2:00     26.987    2.501   17.009  ...      125       87       87      705
#
# ...

# %%
# Plot the day's energy consumption.

dfevent = df_Eng_Sth_Afr_11_24
dtitle = "England vs. South Africa (Rugby): 11/24/2012 14:30 GMT [<0.75m]"
tsb = '14:00'
tse ='16:30'

eventPlotter(dfevent, dtitle, tsb, tse)

# %%
# Plot the day's energy consumption for each Acorn group using a multiline plot.
# extract grouped acorn 

dfevent = df_Eng_Sth_Afr_11_24
dtitle = "England vs. South Africa (Rugby): 11/24/2012 14:30 GMT [<0.75m]"
tsb = '14:00'
tse ='16:30'

eventPlotterAcorn( dfevent, dtitle, tsb, tse )

# %%
# Plot the day's normalized energy consumption for each Acorn group using a multiline plot.


dfevent = df_Eng_Sth_Afr_11_24
title = "England vs. South Africa (Rugby): 11/24/2012 14:30 GMT [<0.75m]"
tsb = '14:00'
tse ='16:30'

eventPlotterAcorn(dfevent, title, tsb, tse, breaktime='15:30')

# %% [markdown]
# England Vs. New Zealand (12-1-2012)

# %%
# Create a dataframe representing energy consumption for December 01 2012, the day
# of the England vs. Italy game.

df_England_NewZealand_12_01 = df.loc[df['day']==1].loc[df['month']==12].loc[df['year']==2012]
df_England_NewZealand_12_01 = df_England_NewZealand_12_01.set_index(df_England_NewZealand_12_01["tstamp"])
df_England_NewZealand_12_01.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00             0  2012-12-01 00:00:00  2012     12    1     0       0
# 0:30             1  2012-12-01 00:30:00  2012     12    1     0      30
# 1:00             2  2012-12-01 01:00:00  2012     12    1     1       0
# 1:30             3  2012-12-01 01:30:00  2012     12    1     1      30
# 2:00             4  2012-12-01 02:00:00  2012     12    1     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00     49.712    4.840   27.291  ...      125       87       86      706
# 0:30     42.270    3.919   24.144  ...      125       87       87      706
# 1:00     34.621    3.012   21.683  ...      125       87       87      706
# 1:30     28.279    2.805   18.645  ...      125       87       87      706
# 2:00     30.286    2.240   16.981  ...      125       87       87      706
#
# ...

# %%
# Enter details for the England vs. France game, which took place on day 01
# between 14:30 and 15:30 (approx).

dfevent = df_England_NewZealand_12_01
title   = "England vs. New Zealand (Rugby): 12/01/2012 14:30 GMT [0.75m]"
tsb     = '14:30'
tse     = '15:30'

# Plot the day's energy consumption.

eventPlotter(dfevent, title, tsb, tse)

# %%
dfevent = df_England_NewZealand_12_01
dtitle   = "England vs. New Zealand (Rugby): 12/01/2012 14:30 GMT [0.75m]"
tsb     = '14:30'
tse     = '15:30'

eventPlotterAcorn(dfevent, dtitle, tsb, tse)

# %%
dfevent = df_England_NewZealand_12_01
title   = "England vs. New Zealand (Rugby): 12/01/2012 14:30 GMT [0.75m]"
tsb     = '14:30'
tse     = '15:30'


eventPlotterAcorn(dfevent, title, tsb, tse, breaktime='19:00')

# %% [markdown]
# England Vs. Italy (02-11-2012)

# %%
# Create a dataframe representing energy consumption for February 11th 2012, the day
# of the England vs. Italy game.

df_England_Italy_2_11 =  df.loc[df['day']==11].loc[df['month']==2].loc[df['year']==2012]
df_England_Italy_2_11 = df_England_Italy_2_11.set_index(df_England_Italy_2_11["tstamp"])
df_England_Italy_2_11.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00           480  2012-02-11 00:00:00  2012      2   11     0       0
# 0:30           481  2012-02-11 00:30:00  2012      2   11     0      30
# 1:00           482  2012-02-11 01:00:00  2012      2   11     1       0
# 1:30           483  2012-02-11 01:30:00  2012      2   11     1      30
# 2:00           484  2012-02-11 02:00:00  2012      2   11     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00      5.162    0.101    2.609  ...        3        4        9       87
# 0:30      5.763    0.141    1.589  ...        3        4        9       87
# 1:00      5.561    0.070    1.434  ...        3        4        9       87
# 1:30      4.040    0.099    1.398  ...        3        4        9       87
# 2:00      3.106    0.060    1.282  ...        3        4        9       87
#
# ...

# %%
# Plot the day's energy consumption.

dfevent = df_England_Italy_2_11
dtitle = "England vs. Italy (Rugby): 2/11/2012 16:00 GMT [5.03m]"
tsb = '16:00'
tse ='18:00'

eventPlotter(dfevent, dtitle, tsb, tse)

# %%
# Plot the day's energy consumption for each Acorn group using a multiline plot.
# extract grouped acorn 

dfevent = df_England_Italy_2_11
dtitle = "England vs. Italy (Rugby): 2/11/2012 16:00 GMT [5.03m]"
tsb = '16:00'
tse ='18:00'

eventPlotterAcorn( dfevent, dtitle, tsb, tse )

# %%
# Plot the day's normalized energy consumption for each Acorn group using a multiline plot.


dfevent = df_England_Italy_2_11
title = "England vs. Italy (Rugby): 2/11/2012 16:00 GMT [5.03m]"
tsb = '16:00'
tse ='18:00'

eventPlotterAcorn(dfevent, title, tsb, tse, breaktime='13:30')

# %% [markdown]
# England Vs Scotland(02-04-2012)

# %%
# Create a dataframe representing energy consumption for February 4th 2012, the day
# of the England vs. Scotland game.

df_England_Scotland_2_4 = df.loc[df['day']==4].loc[df['month']==2].loc[df['year']==2012]
df_England_Scotland_2_4 = df_England_Scotland_2_4.set_index(df_England_Scotland_2_4["tstamp"])
df_England_Scotland_2_4.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00           144  2012-02-04 00:00:00  2012      2    4     0       0
# 0:30           145  2012-02-04 00:30:00  2012      2    4     0      30
# 1:00           146  2012-02-04 01:00:00  2012      2    4     1       0
# 1:30           147  2012-02-04 01:30:00  2012      2    4     1      30
# 2:00           148  2012-02-04 02:00:00  2012      2    4     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00      5.243    0.118    2.938  ...        3        4        8       81
# 0:30      5.508    0.116    1.772  ...        3        4        8       81
# 1:00      5.679    0.136    1.072  ...        3        4        8       81
# 1:30      4.820    0.171    1.049  ...        3        4        8       81
# 2:00      4.063    0.106    1.005  ...        3        4        8       81
#
# ...

# %%
# Enter details for the England vs. Scotland game, which took place on day 4
# between 17:00 and 19:00 (approx).

dfevent = df_England_Scotland_2_4
title   = "England vs. Scotland (Rugby): 2/4/2012 17:00 GMT [6.48m]"
tsb     = '17:00'
tse     = '19:00'

# Plot the day's energy consumption.

eventPlotter(dfevent, title, tsb, tse)

# %%
# Plot the day's energy consumption for each Acorn group using a multiline plot.
# extract grouped acorn 

dfevent = df_England_Scotland_2_4
dtitle   = "England vs. Scotland (Rugby): 2/4/2012 17:00 GMT [6.48m]"
tsb     = '17:00'
tse     = '19:00'


eventPlotterAcorn( dfevent, dtitle, tsb, tse )

# %%
# Plot the day's normalized energy consumption for each Acorn group using a multiline plot.


dfevent = df_England_Scotland_2_4
title   = "England vs. Scotland (Rugby): 2/4/2012 17:00 GMT [6.48m]"
tsb     = '17:00'
tse     = '19:00'

eventPlotterAcorn(dfevent, title, tsb, tse, breaktime='16:30')

# %% [markdown]
# England Vs. Wales(02-25-12)

# %%
# Create a dataframe representing energy consumption for February 25th 2012, the day
# of the England vs. Wales game.

df_England_Wales_2_25 = df.loc[df['day']==25].loc[df['month']==2].loc[df['year']==2012]
df_England_Wales_2_25 = df_England_Wales_2_25.set_index(df_England_Wales_2_25["tstamp"])
df_England_Wales_2_25.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00          1152  2012-02-25 00:00:00  2012      2   25     0       0
# 0:30          1153  2012-02-25 00:30:00  2012      2   25     0      30
# 1:00          1154  2012-02-25 01:00:00  2012      2   25     1       0
# 1:30          1155  2012-02-25 01:30:00  2012      2   25     1      30
# 2:00          1156  2012-02-25 02:00:00  2012      2   25     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00      4.625    0.133    1.879  ...        3        4       23       96
# 0:30      3.973    0.061    2.030  ...        3        4       23       95
# 1:00      3.865    0.147    1.327  ...        3        4       23       95
# 1:30      3.397    0.135    1.300  ...        3        4       23       95
# 2:00      2.877    0.103    1.057  ...        3        4       23       95
#
# ...

# %%
# Enter details for the England vs. Wales game, which took place on day 25
# between 16:00 and 18:00 (approx).

dfevent = df_England_Wales_2_25
title   = "England vs. Wales (Rugby): 2/25/2012 16:00 GMT [5.66m]"
tsb     = '16:00'
tse     = '18:00'

# Plot the day's energy consumption.

eventPlotter(dfevent, title, tsb, tse)

# %%
# Plot the day's energy consumption for each Acorn group using a multiline plot.
# extract grouped acorn 

dfevent = df_England_Wales_2_25
dtitle   = "England vs. Wales (Rugby): 2/25/2012 16:00 GMT [5.66m]"
tsb     = '16:00'
tse     = '18:00'


eventPlotterAcorn( dfevent, dtitle, tsb, tse )

# %%
# Plot the day's normalized energy consumption for each Acorn group using a multiline plot.


dfevent = df_England_Wales_2_25
title   = "England vs. Wales (Rugby): 2/25/2012 16:00 GMT [5.66m]"
tsb     = '16:00'
tse     = '18:00'

eventPlotterAcorn(dfevent, title, tsb, tse, breaktime='17:30')

# %% [markdown]
# England Vs. France (03-11-2012)

# %%
# Create a dataframe representing energy consumption for March 11th 2012, the day
# of the England vs. France game.

df_England_France_3_11 = df.loc[df['day']==11].loc[df['month']==3].loc[df['year']==2012]
df_England_France_3_11 = df_England_France_3_11.set_index(df_England_France_3_11["tstamp"])
df_England_France_3_11.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00           480  2012-03-11 00:00:00  2012      3   11     0       0
# 0:30           481  2012-03-11 00:30:00  2012      3   11     0      30
# 1:00           482  2012-03-11 01:00:00  2012      3   11     1       0
# 1:30           483  2012-03-11 01:30:00  2012      3   11     1      30
# 2:00           484  2012-03-11 02:00:00  2012      3   11     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00      7.829    0.064    3.489  ...        4        4       30      106
# 0:30      6.424    0.076    1.872  ...        4        4       30      106
# 1:00      4.440    0.108    1.864  ...        4        4       30      106
# 1:30      5.591    0.099    1.693  ...        4        4       30      106
# 2:00      5.334    0.064    1.273  ...        4        4       30      106
#
# ...

# %%
# Enter details for the England vs. France game, which took place on day 11
# between 15:00 and 17:00 (approx).

dfevent = df_England_France_3_11
title   = "England vs. France (Rugby): 3/11/2012 15:00 GMT [4.51m]"
tsb     = '15:00'
tse     = '17:00'

# Plot the day's energy consumption.

eventPlotter(dfevent, title, tsb, tse)

# %%
# Plot the day's energy consumption for each Acorn group using a multiline plot.
# extract grouped acorn 

dfevent = df_England_France_3_11
dtitle   = "England vs. France (Rugby): 3/11/2012 15:00 GMT [4.51m]"
tsb     = '15:00'
tse     = '17:00'


eventPlotterAcorn( dfevent, dtitle, tsb, tse )

# %%
# Plot the day's normalized energy consumption for each Acorn group using a multiline plot.


dfevent = df_England_France_3_11
title   = "England vs. France (Rugby): 3/11/2012 15:00 GMT [4.51m]"
tsb     = '15:00'
tse     = '17:00'

eventPlotterAcorn(dfevent, title, tsb, tse, breaktime='16:30')

# %% [markdown]
# England Vs. Ireland(03-17-2012)

# %%
# Create a dataframe representing energy consumption for March 17th 2012, the day
# of the England vs. Ireland game.

df_England_Ireland_3_17 = df.loc[df['day']==17].loc[df['month']==3].loc[df['year']==2012]
df_England_Ireland_3_17 = df_England_Ireland_3_17.set_index(df_England_Ireland_3_17["tstamp"])
df_England_Ireland_3_17.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00           768  2012-03-17 00:00:00  2012      3   17     0       0
# 0:30           769  2012-03-17 00:30:00  2012      3   17     0      30
# 1:00           770  2012-03-17 01:00:00  2012      3   17     1       0
# 1:30           771  2012-03-17 01:30:00  2012      3   17     1      30
# 2:00           772  2012-03-17 02:00:00  2012      3   17     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00      8.184    0.088    3.480  ...        5        7       30      118
# 0:30      6.373    0.133    2.193  ...        5        7       30      118
# 1:00      5.028    0.072    1.897  ...        5        7       30      118
# 1:30      5.397    0.060    1.677  ...        5        7       30      118
# 2:00      4.573    0.153    1.553  ...        5        7       30      118
#
# ...

# %%
# Enter details for the England vs. Ireland game, which took place on day 17
# between 17:00 and 19:00 (approx).

dfevent = df_England_Ireland_3_17
title   = "England vs. Ireland (Rugby): 3/17/2012 17:00 GMT [5.76m]"
tsb     = '17:00'
tse     = '19:00'

# Plot the day's energy consumption.

eventPlotter(dfevent, title, tsb, tse)

# %%
# Plot the day's energy consumption for each Acorn group using a multiline plot.
# extract grouped acorn 

dfevent = df_England_Ireland_3_17
title   = "England vs. Ireland (Rugby): 3/17/2012 17:00 GMT [5.76m]"
tsb     = '17:00'
tse     = '19:00'


eventPlotterAcorn( dfevent, dtitle, tsb, tse )

# %%
# Plot the day's normalized energy consumption for each Acorn group using a multiline plot.


dfevent = df_England_Ireland_3_17
title   = "England vs. Ireland (Rugby): 3/17/2012 17:00 GMT [5.76m]"
tsb     = '17:00'
tse     = '19:00'

eventPlotterAcorn(dfevent, title, tsb, tse, breaktime='18:00')
