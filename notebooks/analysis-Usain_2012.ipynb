# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import pandas as pd

from pickup_utilities import *
df = pd.read_csv("../data/complete.csv")
df['tstamp'] = df.apply(tstampCalc, axis = 1)

# %%
Usain_8_05 = df.loc[df['day']==5].loc[df['month']==8].loc[df['year']==2012]
df_Usain_8_05 = Usain_8_05.set_index(Usain_8_05["tstamp"])
df_Usain_8_05.head(5)
# Out:
#         Unnamed: 0             datetime  year  month  day  hour  minute  \
# tstamp
# 0:00           192  2012-08-05 00:00:00  2012      8    5     0       0
# 0:30           193  2012-08-05 00:30:00  2012      8    5     0      30
# 1:00           194  2012-08-05 01:00:00  2012      8    5     1       0
# 1:30           195  2012-08-05 01:30:00  2012      8    5     1      30
# 2:00           196  2012-08-05 02:00:00  2012      8    5     2       0
#
#         A_sigma  B_sigma  C_sigma  ...  N_count  O_count  P_count  Q_count  \
# tstamp                             ...
# 0:00     21.586    1.464   14.703  ...       88       60       83      676
# 0:30     20.538    1.167   10.804  ...       89       60       82      676
# 1:00     18.638    1.173   10.516  ...       89       60       82      676
# 1:30     20.171    0.995    9.368  ...       89       60       82      676
# 2:00     19.305    1.169    7.966  ...       89       60       82      676
#
# ...

# %%
# Enter details for the Usain Bolt's 100 meter's final which took place on day 8th
# between 21.50 and 21.55 (approx).

dfevent = df_Usain_8_05
title   = "Usain_Bolt_100m_final: 8/05/2012 21:50 GMT (20 mil)"
tsb     = '21:30'
tse     = '22:30'

# Plot the day's energy consumption.

eventPlotter(dfevent, title, tsb, tse)

# %%
# Plot the day's energy consumption for each Acorn group using a multiline plot.
# extract grouped acorn 

dfevent=  df_Usain_8_05
dtitle = "Usain_Bolt_100m_final: 8/05/2012 21:50 GMT [20 mil]"
tsb   = '21:30'
tse   = '22:30'

eventPlotterAcorn( dfevent, dtitle, tsb, tse )
